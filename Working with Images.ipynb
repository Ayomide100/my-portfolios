# %%
# !pip install opencv-python

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread("licensed-image.jpeg")

# %%
img
# Out:
# array([[[154, 135, 132],
#         [155, 136, 133],
#         [157, 138, 135],
#         ...,
#         [ 98,  97, 106],
#         [ 99,  98, 107],
#         [100,  99, 108]],
#
#        [[155, 136, 133],
#         [156, 137, 134],
#         [157, 138, 135],
#         ...,
#         [ 98,  97, 106],
#         [ 99,  98, 107],
#         [100,  99, 108]],
#
#        [[156, 137, 134],
#         [157, 138, 135],
#         [158, 139, 136],
#         ...,
#         [ 99,  98, 107],
#         [ 99,  98, 107],
#         [100,  99, 108]],
#
#        ...,
#
#        [[159, 153, 170],
#         [159, 153, 170],
#         [160, 154, 171],
#         ...,
#         [ 77,  99, 117],
#         [ 76,  98, 116],
#         [ 75,  97, 115]],
#
#        [[162, 156, 173],
#         [162, 156, 173],
#         [161, 155, 172],
#         ...,
#         [ 77,  99, 117],
#         [ 76,  98, 116],
#         [ 75,  97, 115]],
#
#        [[164, 158, 175],
#         [163, 157, 174],
#         [162, 156, 173],
#         ...,
#         [ 77,  99, 117],
#         [ 76,  98, 116],
#         [ 75,  97, 115]]], dtype=uint8)

# %%
# Convert images to greyscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img_gray
# Out:
# array([[136, 137, 139, ..., 100, 101, 102],
#        [137, 138, 139, ..., 100, 101, 102],
#        [138, 139, 140, ..., 101, 101, 102],
#        ...,
#        [159, 159, 160, ..., 102, 101, 100],
#        [162, 162, 161, ..., 102, 101, 100],
#        [164, 163, 162, ..., 102, 101, 100]], dtype=uint8)

# %%
plt.imshow(img_gray, cmap="gray")
plt.show()

# %%
# img_gray.shape()

# %%
# Convert grey_scale image to an array
img_arr = np.array(img_gray)

# %%
img_arr.shape
# Out:
# (1366, 2048)

# %%
img_arr
# Out:
# array([[136, 137, 139, ..., 100, 101, 102],
#        [137, 138, 139, ..., 100, 101, 102],
#        [138, 139, 140, ..., 101, 101, 102],
#        ...,
#        [159, 159, 160, ..., 102, 101, 100],
#        [162, 162, 161, ..., 102, 101, 100],
#        [164, 163, 162, ..., 102, 101, 100]], dtype=uint8)

# %%
#Resize image using cv2
cv2.resize(img, (64, 64))
# Out:
# array([[[159, 142, 139],
#         [160, 145, 135],
#         [163, 151, 144],
#         ...,
#         [ 97,  98, 108],
#         [ 99, 100, 109],
#         [103, 101, 110]],
#
#        [[163, 144, 137],
#         [160, 144, 136],
#         [163, 148, 140],
#         ...,
#         [ 97,  98, 109],
#         [ 95,  96, 107],
#         [ 96,  98, 107]],
#
#        [[158, 140, 134],
#         [162, 145, 138],
#         [163, 147, 140],
#         ...,
#         [ 93,  95, 110],
#         [ 96,  96, 111],
#         [ 91,  93, 104]],
#
#        ...,
#
#        [[169, 163, 186],
#         [164, 158, 182],
#         [160, 155, 179],
#         ...,
#         [122, 127, 138],
#         [105, 114, 125],
#         [ 92, 108, 121]],
#
#        [[165, 158, 180],
#         [159, 153, 175],
#         [150, 144, 166],
#         ...,
#         [116, 123, 137],
#         [ 96, 110, 128],
#         [ 86, 101, 118]],
#
#        [[160, 156, 175],
#         [153, 150, 166],
#         [147, 144, 164],
#         ...,
#         [116, 123, 142],
#         [ 96, 108, 127],
#         [ 81,  98, 115]]], dtype=uint8)

# %%
# Convert 2d array to 1D
img_arr.flatten()
# Out:
# array([136, 137, 139, ..., 102, 101, 100], dtype=uint8)
